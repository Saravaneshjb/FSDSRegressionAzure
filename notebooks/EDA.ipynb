# %%
import pandas as pd

# %%
#Data Ingestion step
df=pd.read_csv('data/gemstone.csv')
df.head()
# Out:
#    Unnamed: 0  carat        cut color clarity  depth  table     x     y     z
# 0           1   0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66  \
# 1           2   0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70
# 2           3   0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78
# 3           4   0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96
# 4           5   0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65
#
#    price
# 0    499
# 1    984
# 2   6289
# 3   1082
# 4    779

# %%
#Checking for missing values
df.isna().sum()
# Out:
# Unnamed: 0      0
# carat           0
# cut             0
# color           0
# clarity         0
# depth         697
# table           0
# x               0
# y               0
# z               0
# price           0
# dtype: int64

# %% [markdown]
# ### Missing values present in the field depth

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26967 entries, 0 to 26966
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  26967 non-null  int64
#  1   carat       26967 non-null  float64
#  2   cut         26967 non-null  object
#  3   color       26967 non-null  object
#  4   clarity     26967 non-null  object
#  5   depth       26270 non-null  float64
#  6   table       26967 non-null  float64
#  7   x           26967 non-null  float64
#  8   y           26967 non-null  float64
#  9   z           26967 non-null  float64
#  10  price       26967 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 2.3+ MB

# %%
#Dropping the unamed column
df.drop(labels=['Unnamed: 0'], axis=1,inplace=True)
df.head()
# Out:
#    carat        cut color clarity  depth  table     x     y     z  price
# 0   0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66    499
# 1   0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70    984
# 2   0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78   6289
# 3   0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96   1082
# 4   0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65    779

# %%
#Check for duplicate records
df.duplicated().sum()
# Out:
# 34

# %% [markdown]
# ### In total there are 34 duplicates and they are shown below.

# %%
df[df.duplicated()]
# Out:
#        carat        cut color clarity  depth  table     x     y     z  price
# 4756    0.35    Premium     J     VS1   62.4   58.0  5.67  5.64  3.53    949
# 6215    0.71       Good     F     SI2   64.1   60.0  0.00  0.00  0.00   2130
# 8144    0.33      Ideal     G     VS1   62.1   55.0  4.46  4.43  2.76    854
# 8919    1.52       Good     E      I1   57.3   58.0  7.53  7.42  4.28   3105
# 9818    0.35      Ideal     F     VS2   61.4   54.0  4.58  4.54  2.80    906
# 10473   0.79      Ideal     G     SI1   62.3   57.0  5.90  5.85  3.66   2898
# 10500   1.00    Premium     F    VVS2   60.6   54.0  6.56  6.52  3.96   8924
# 12894   1.21    Premium     D     SI2   62.5   57.0  6.79  6.71  4.22   6505
# 13547   0.43      Ideal     G     VS1   61.9   55.0  4.84  4.86  3.00    943
# 13783   0.79      Ideal     G     SI1   62.3   57.0  5.90  5.85  3.66   2898
# 14389   0.60    Premium     D     SI2   62.0   57.0  5.43  5.35  3.34   1196
# ...

# %% [markdown]
# ### drop duplicates

# %%
print('Length of dataset before dropping :',len(df))
df.drop_duplicates(inplace=True)
print('Length of dataset after dropping :',len(df))
# Out:
# Length of dataset before dropping : 26967
# Length of dataset after dropping : 26933

# %% [markdown]
# ### Drop NA values

# %%
print(df.isna().sum())
df.dropna(inplace=True)
print(df.isna().sum())
# Out:
# carat        0
# cut          0
# color        0
# clarity      0
# depth      697
# table        0
# x            0
# y            0
# z            0
# price        0
# dtype: int64
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %% [markdown]
# ### Segregate the features to Qualitative, Quantitative

# %%
Quantitative_Features=[features for features in df.columns if df[features].dtype!='object']
Qualitative_Features=[features for features in df.columns if df[features].dtype=='object']
print('Quantitative features :', Quantitative_Features)
print('Qualitative features :', Qualitative_Features)
# Out:
# Quantitative features : ['carat', 'depth', 'table', 'x', 'y', 'z', 'price']
# Qualitative features : ['cut', 'color', 'clarity']

# %%
Discrete_Features=[features for features in Quantitative_Features if len(df['carat'].unique()) < 20]
Continous_Features=[features for features in Quantitative_Features if features not in Discrete_Features]

print('The Discrete Features are :',Discrete_Features)
print('The Continous Features are :',Continous_Features)
# Out:
# The Discrete Features are : []
# The Continous Features are : ['carat', 'depth', 'table', 'x', 'y', 'z', 'price']

# %%
df[Qualitative_Features].describe()
# Out:
#           cut  color clarity
# count   26236  26236   26236
# unique      5      7       8
# top     Ideal      G     SI1
# freq    10535   5521    6402

# %%
df['cut'].unique()
# Out:
# array(['Ideal', 'Premium', 'Very Good', 'Good', 'Fair'], dtype=object)

# %%
df['cut'].nunique()
# Out:
# 5

# %%
df['cut'].value_counts()
# Out:
# cut
# Ideal        10535
# Premium       6694
# Very Good     5875
# Good          2376
# Fair           756
# Name: count, dtype: int64

# %%
df['clarity'].value_counts()
# Out:
# clarity
# SI1     6402
# VS2     5919
# SI2     4436
# VS1     3985
# VVS2    2478
# VVS1    1791
# IF       871
# I1       354
# Name: count, dtype: int64

# %%
df['color'].value_counts()
# Out:
# color
# G    5521
# E    4792
# F    4606
# H    3984
# D    3265
# I    2670
# J    1398
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
x=1
for i in Quantitative_Features:
    sns.histplot(data=df,x=i,kde=True)
    print('\n')
    plt.show()

# %%
### Assignment - Do the same for Categorical variables 
for i in Qualitative_Features:
    sns.displot(x=i,data=df)

# %% [markdown]
# ### Plot Avg Price wrt each categorical feature

# %%
for feature in Qualitative_Features:
    print(feature)
    df.groupby(feature)['price'].mean().sort_values(ascending=False).plot.bar()
    plt.xlabel(feature)
    plt.ylabel('Price')
    plt.show()
# Out:
# cut
# color
# clarity

# %%
### Correlation 
sns.heatmap(df[Quantitative_Features].corr(),annot=True)
# Out:
# <Axes: >

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def calc_vif(X):

    # Calculating VIF
    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

    return(vif)

# %%
df.values
# range(df.shape[1])
# Out:
# array([[0.3, 'Ideal', 'E', ..., 62.1, 58.0, 499],
#        [0.33, 'Premium', 'G', ..., 60.8, 58.0, 984],
#        [0.9, 'Very Good', 'E', ..., 62.2, 60.0, 6289],
#        ...,
#        [0.51, 'Premium', 'E', ..., 61.7, 58.0, 1656],
#        [0.27, 'Very Good', 'F', ..., 61.8, 56.0, 682],
#        [1.25, 'Premium', 'J', ..., 62.0, 58.0, 5166]], dtype=object)

# %%
calc_vif(df[Quantitative_Features])
# Out:
#   variables          VIF
# 0     carat   115.172661
# 1     depth   652.233325
# 2     table   569.716542
# 3         x  1587.630426
# 4         y   351.114678
# 5         z  1434.204806
# 6     price    13.604433

# %% [markdown]
# ### Looks like x,y,z seem to have high correlation hence dropping them and proceeding.

# %%
df.drop(['x','y','z'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    carat        cut color clarity  depth  table  price
# 0   0.30      Ideal     E     SI1   62.1   58.0    499
# 1   0.33    Premium     G      IF   60.8   58.0    984
# 2   0.90  Very Good     E    VVS2   62.2   60.0   6289
# 3   0.42      Ideal     F     VS1   61.6   56.0   1082
# 4   0.31      Ideal     F    VVS1   60.4   59.0    779

# %%
Quantitative_Features = [features for features in df.columns if df[features].dtype!='object']
Quantitative_Features
# Out:
# ['carat', 'depth', 'table', 'price']

# %%
df[Quantitative_Features].corr()
# Out:
#           carat     depth     table     price
# carat  1.000000  0.035240  0.181621  0.922125
# depth  0.035240  1.000000 -0.297768 -0.002895
# table  0.181621 -0.297768  1.000000  0.126485
# price  0.922125 -0.002895  0.126485  1.000000

# %%
sns.heatmap(df[Quantitative_Features].corr(),annot=True)
# Out:
# <Axes: >

# %%
calc_vif(df[Quantitative_Features])
# Out:
#   variables         VIF
# 0     carat   25.915114
# 1     depth  393.109556
# 2     table  401.999139
# 3     price   13.205723

# %%
sns.pairplot(df)

# %% [markdown]
# ### Working on Categorical features

# %%
df.head()
# Out:
#    carat        cut color clarity  depth  table  price
# 0   0.30      Ideal     E     SI1   62.1   58.0    499
# 1   0.33    Premium     G      IF   60.8   58.0    984
# 2   0.90  Very Good     E    VVS2   62.2   60.0   6289
# 3   0.42      Ideal     F     VS1   61.6   56.0   1082
# 4   0.31      Ideal     F    VVS1   60.4   59.0    779

# %%
df['cut'].unique()
# Out:
# array(['Ideal', 'Premium', 'Very Good', 'Good', 'Fair'], dtype=object)

# %%
cut_map={'Fair':1,"Good":2,"Very Good":3,"Premium":4,"Ideal":5}

# %%
df['clarity'].unique()
# Out:
# array(['SI1', 'IF', 'VVS2', 'VS1', 'VVS1', 'VS2', 'SI2', 'I1'],
#       dtype=object)

# %%
clarity_map = {"I1":1,"SI2":2,"SI1":3,"VS2":4,"VS1":5,"VVS2":6,"VVS1":7,"IF":8}

# %%
df['color'].unique()
# Out:
# array(['E', 'G', 'F', 'D', 'H', 'J', 'I'], dtype=object)

# %%
color_map={"D":1,"E":2,"F":3,"G":4,"H":5,"I":6,"J":7}

# %%
# df['cut'].replace(cut_map)
df['cut']=df['cut'].map(cut_map)
df['clarity']=df['clarity'].map(clarity_map)
df['color']=df['color'].map(color_map)

# %%
df.head()
# Out:
#    carat  cut  color  clarity  depth  table  price
# 0   0.30    5      2        3   62.1   58.0    499
# 1   0.33    4      4        8   60.8   58.0    984
# 2   0.90    3      2        6   62.2   60.0   6289
# 3   0.42    5      3        5   61.6   56.0   1082
# 4   0.31    5      3        7   60.4   59.0    779
